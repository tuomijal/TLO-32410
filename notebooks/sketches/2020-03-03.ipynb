# %%
import pandas as pd
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
import geopandas as gpd
from pyprojroot import here
import numpy as np

# %matplotlib inline

# up figure resolution
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi']= 150

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# In this notebooks, we will perfrorm some exploratory data analysis on Inside AirBnB's [Barcelona dataset](http://insideairbnb.com/barcelona/). The dataset contains seven files, each of which will be investigated in more detail.
#
# - detailed
#     - calendar
#     - listings
#     - reviews
# - summary
#     - listings
#     - reviews
# - geospatial
#     - neighbourhoods.csv
#     - neighbourhoods.geojson

# %%
# %%time
listings_detailed = pd.read_csv("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/data/listings.csv.gz")
# Out:
# CPU times: user 1.88 s, sys: 483 ms, total: 2.36 s
# Wall time: 11.7 s

# %%
price = listings_detailed.price.str[1:].replace("$", '')
price = price.str.replace(',', '')
listings_detailed.price = price.astype(float)
listings_detailed = listings_detailed[listings_detailed.price!=0]

listings_detailed['price_log'] = np.log(listings_detailed.price)

# %%
# Out:
# Index(['price', 'weekly_price', 'monthly_price', 'price_log'], dtype='object')

# %%
listings_detailed[listings_detailed.price_log == -np.inf]
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, name, summary, space, description, experiences_offered, neighborhood_overview, notes, transit, access, interaction, house_rules, thumbnail_url, medium_url, picture_url, xl_picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, requires_license, license, jurisdiction_names, instant_bookable, is_business_travel_ready, cancellation_policy, require_guest_profile_picture, ...]
# Index: []

# %%
listings_detailed.price_log.describe()
# Out:
# count    20980.000000
# mean         4.221513
# std          0.894703
# min          1.791759
# 25%          3.610918
# 50%          4.094345
# 75%          4.653960
# max          9.615805
# Name: price_log, dtype: float64

# %%
listings_detailed.shape
# Out:
# (20981, 106)

# %%
listings_detailed
# Out:
#              id                            listing_url       scrape_id  \
# 0         18674     https://www.airbnb.com/rooms/18674  20200216165356
# 1         23197     https://www.airbnb.com/rooms/23197  20200216165356
# 2         25786     https://www.airbnb.com/rooms/25786  20200216165356
# 3         31958     https://www.airbnb.com/rooms/31958  20200216165356
# 4         32471     https://www.airbnb.com/rooms/32471  20200216165356
# ...         ...                                    ...             ...
# 20976  42319864  https://www.airbnb.com/rooms/42319864  20200216165356
# 20977  42320116  https://www.airbnb.com/rooms/42320116  20200216165356
# 20978  42320241  https://www.airbnb.com/rooms/42320241  20200216165356
# 20979  42320286  https://www.airbnb.com/rooms/42320286  20200216165356
# 20980  42322705  https://www.airbnb.com/rooms/42322705  20200216165356
#
#       last_scraped                                               name  \
# 0       2020-02-16    Huge flat for 8 people close to Sagrada Familia
# 1       2020-02-16    Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
# 2       2020-02-16         NICE ROOM AVAILABLE IN THE HEART OF GRACIA
# 3       2020-02-16                    Gaudi Attic 1, Friendly Rentals
# 4       2020-02-16                    Gaudi Attic 2, Friendly Rentals
# ...            ...                                                ...
# 20976   2020-02-16                             Room near the beach ☀️
# 20977   2020-02-16  Double room in minimal flat close to beach & city
# 20978   2020-02-16                Double room private toilet near UAB
# 20979   2020-02-16             Cozy apartment (downtown of Barcelona)
# 20980   2020-02-16                                ROOM IN THE CENTER!
#
#                                                  summary  \
# 0      110m2 apartment to rent in Barcelona. Located ...
# 1      I do not accept groups of young people under 2...
# 2      JUST GO THROUGH THE MANY REVIEWS I GOT THROUGH...
# 3      This apartment has: 1 double bed, 1 double sof...
# 4      Diese Wohnung verfügt über: 2 Doppelbetten, 1 ...
# ...                                                  ...
# 20976                                                NaN
# 20977  Private double bedroom with access to balcony....
# 20978            Sunrise sun at the room. Private toilet
# 20979  Sunny apartment in the city center  with a dob...
# 20980  Piso grande y luminoso en el centro de barcelo...
#
#                                                    space  \
# 0      Apartment with 110 m2 located in the 6th floor...
# 1      Elegant spacious apartment suitable for 6. Amp...
# 2      Room available for rent.-  PEDRO PEREZ.  Share...
# 3      This apartment has: 1 double bed, 1 double sof...
# 4      Diese Wohnung verfügt über: 2 Doppelbetten, 1 ...
# ...                                                  ...
# 20976                                                NaN
# 20977                                                NaN
# 20978                                                NaN
# 20979  Bedroom ( Doble bed,air conditioning, televiso...
# 20980  Grande y luminoso. La habitación tiene cama do...
#
#                                              description experiences_offered  \
# 0      110m2 apartment to rent in Barcelona. Located ...                none
# 1      I do not accept groups of young people under 2...                none
# 2      JUST GO THROUGH THE MANY REVIEWS I GOT THROUGH...                none
# 3      This apartment has: 1 double bed, 1 double sof...                none
# 4      Diese Wohnung verfügt über: 2 Doppelbetten, 1 ...                none
# ...                                                  ...                 ...
# 20976                                                NaN                none
# 20977  Private double bedroom with access to balcony....                none
# 20978            Sunrise sun at the room. Private toilet                none
# 20979  Sunny apartment in the city center  with a dob...                none
# 20980  Piso grande y luminoso en el centro de barcelo...                none
#
#                                    neighborhood_overview  \
# 0      Apartment in Barcelona located in the heart of...
# 1      Strategically located in the area of Parc del ...
# 2      Solo decir que a menudo ni salgo del barrio. M...
# 3      Looking for apartments in Gràcia, Barcelona fo...
# 4      Looking for apartments in Gràcia, Barcelona fo...
# ...                                                  ...
# 20976                                                NaN
# 20977                                                NaN
# 20978                                                NaN
# 20979  Historical Neighborhood in the heart of Barcel...
# 20980                    Excelente, tranquilo y centrico
#
#                                                    notes  \
# 0                                                    NaN
# 1      As a Superhost, I aim to make your stay as com...
# 2      No dudes en perdir una cita para un masaje rel...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20976                                                NaN
# 20977                                                NaN
# 20978                                                NaN
# 20979                                                NaN
# 20980                                                NaN
#
#                                                  transit  \
# 0      Good transport connection,  150 m from metro “...
# 1      Tram   T4  Campus Diagonal- Besos, over the ro...
# 2      Metro con las principales estaciones. A pie. E...
# 3      Ideaal om te voet of met het openbaar vervoer ...
# 4      Perfekt um die Stadt per Fuß oder öffentliche ...
# ...                                                  ...
# 20976                                                NaN
# 20977                                                NaN
# 20978                                                NaN
# 20979  Subway station 'Rocafort' line 1, on the backs...
# 20980                                              L3 L1
#
#                                                   access  \
# 0      Free Wifi - air conditioning. We will provide ...
# 1          You book the entire apartment for yourselves.
# 2      All access with respect. Kitchen facilities ne...
# 3      Gasten hebben toegang tot het gehele appartement.
# 4      Gli ospiti avranno accesso all'intero appartam...
# ...                                                  ...
# 20976                                                NaN
# 20977                                                NaN
# 20978                                                NaN
# 20979                                                NaN
# 20980                                                NaN
#
#                                              interaction  \
# 0      We can provide you all kind of entrance and ti...
# 1      Please do contact Tony, your check-in manager,...
# 2      Available for interaction. Nonproblem feel fre...
# 3      Wij helpen u graag met al uw vragen. Wij kunne...
# 4      Saremo lieti di aiutarvi con qualsiasi cosa di...
# ...                                                  ...
# 20976                                                NaN
# 20977                                                NaN
# 20978                                                NaN
# 20979                                                NaN
# 20980                                                NaN
#
#                                              house_rules  thumbnail_url  \
# 0      Tasa turistica a pagar a la llegada: 2.48 euro...            NaN
# 1      I do not accept groups of young people under 2...            NaN
# 2      Clean Bathroom after use and quick shower At a...            NaN
# 3      CHECK-IN Week Days: The check-in and key colle...            NaN
# 4      CHECK-IN Week Days: The check-in and key colle...            NaN
# ...                                                  ...            ...
# 20976                                                NaN            NaN
# 20977                                                NaN            NaN
# 20978                                                NaN            NaN
# 20979  It's not permitted noise after 10 pm It's just...            NaN
# 20980                                                NaN            NaN
#
#        medium_url                                        picture_url  \
# 0             NaN  https://a0.muscache.com/im/pictures/13031453/4...
# 1             NaN  https://a0.muscache.com/im/pictures/738532/806...
# 2             NaN  https://a0.muscache.com/im/pictures/6619f0c7-8...
# 3             NaN  https://a0.muscache.com/im/pictures/1ebf9c91-4...
# 4             NaN  https://a0.muscache.com/im/pictures/2aa9bdf6-3...
# ...           ...                                                ...
# 20976         NaN  https://a0.muscache.com/im/pictures/2db338fc-0...
# 20977         NaN  https://a0.muscache.com/im/pictures/50423f62-1...
# 20978         NaN  https://a0.muscache.com/im/pictures/8bc830fc-a...
# 20979         NaN  https://a0.muscache.com/im/pictures/5106719a-4...
# 20980         NaN  https://a0.muscache.com/im/pictures/1169cbbb-d...
#
#        xl_picture_url    host_id                                     host_url  \
# 0                 NaN      71615      https://www.airbnb.com/users/show/71615
# 1                 NaN      90417      https://www.airbnb.com/users/show/90417
# 2                 NaN     108310     https://www.airbnb.com/users/show/108310
# 3                 NaN     136853     https://www.airbnb.com/users/show/136853
# 4                 NaN     136853     https://www.airbnb.com/users/show/136853
# ...               ...        ...                                          ...
# 20976             NaN  336344751  https://www.airbnb.com/users/show/336344751
# 20977             NaN    7219871    https://www.airbnb.com/users/show/7219871
# 20978             NaN   92406636   https://www.airbnb.com/users/show/92406636
# 20979             NaN  183514245  https://www.airbnb.com/users/show/183514245
# 20980             NaN   10445396   https://www.airbnb.com/users/show/10445396
#
#               host_name  host_since                        host_location  \
# 0      Mireia And Maria  2010-01-19          Barcelona, Catalonia, Spain
# 1        Etain (Marnie)  2010-03-09                     Catalonia, Spain
# 2                 Pedro  2010-04-14          Barcelona, Catalonia, Spain
# 3               Fidelio  2010-06-02           Barcelona, Cataluña, Spain
# 4               Fidelio  2010-06-02           Barcelona, Cataluña, Spain
# ...                 ...         ...                                  ...
# 20976             María  2020-02-15          Barcelona, Catalonia, Spain
# 20977          Cristina  2013-07-01  Stockholm, Stockholm County, Sweden
# 20978           Matilde  2016-08-29          Barcelona, Catalonia, Spain
# 20979          Manrique  2018-04-10   Madrid, Community of Madrid, Spain
# 20980         Florencia  2013-12-05          Barcelona, Catalonia, Spain
#
#                                               host_about  host_response_time  \
# 0      We are Mireia (43) & Maria (45), two multiling...      within an hour
# 1      Hi.  I'm Etain, though everyone calls me by my...      within an hour
# 2      Hola!\r\nas i say in my add i look for enthusi...                 NaN
# 3                                                   hi!       within an hour
# 4                                                   hi!       within an hour
# ...                                                  ...                 ...
# 20976                                                NaN                 NaN
# 20977                                                NaN                 NaN
# 20978  Hola! Soy profesora de Pilates y yoga. También...      within an hour
# 20979                                                NaN      within an hour
# 20980  Somos una joven pareja de psicoanalistas que t...  within a few hours
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 0                    99%                  95%                 f
# 1                   100%                 100%                 t
# 2                    NaN                 100%                 t
# 3                    94%                 100%                 f
# 4                    94%                 100%                 f
# ...                  ...                  ...               ...
# 20976                NaN                  NaN                 f
# 20977                NaN                 100%                 f
# 20978               100%                  33%                 f
# 20979               100%                  99%                 f
# 20980                70%                  60%                 f
#
#                                       host_thumbnail_url  \
# 0      https://a0.muscache.com/im/users/71615/profile...
# 1      https://a0.muscache.com/im/users/90417/profile...
# 2      https://a0.muscache.com/im/pictures/user/e02a6...
# 3      https://a0.muscache.com/im/users/136853/profil...
# 4      https://a0.muscache.com/im/users/136853/profil...
# ...                                                  ...
# 20976  https://a0.muscache.com/im/pictures/user/e0f04...
# 20977  https://a0.muscache.com/im/users/7219871/profi...
# 20978  https://a0.muscache.com/im/pictures/user/2413d...
# 20979  https://a0.muscache.com/im/pictures/user/d6ed9...
# 20980  https://a0.muscache.com/im/pictures/user/4f58f...
#
#                                         host_picture_url  \
# 0      https://a0.muscache.com/im/users/71615/profile...
# 1      https://a0.muscache.com/im/users/90417/profile...
# 2      https://a0.muscache.com/im/pictures/user/e02a6...
# 3      https://a0.muscache.com/im/users/136853/profil...
# 4      https://a0.muscache.com/im/users/136853/profil...
# ...                                                  ...
# 20976  https://a0.muscache.com/im/pictures/user/e0f04...
# 20977  https://a0.muscache.com/im/users/7219871/profi...
# 20978  https://a0.muscache.com/im/pictures/user/2413d...
# 20979  https://a0.muscache.com/im/pictures/user/d6ed9...
# 20980  https://a0.muscache.com/im/pictures/user/4f58f...
#
#                     host_neighbourhood  host_listings_count  \
# 0                   la Sagrada Família                 39.0
# 1                El Besòs i el Maresme                  5.0
# 2                       Vila de Gràcia                  1.0
# 3      Camp d'en Grassot i Gràcia Nova                 29.0
# 4      Camp d'en Grassot i Gràcia Nova                 29.0
# ...                                ...                  ...
# 20976                              NaN                  1.0
# 20977                              NaN                  3.0
# 20978           Sant Andreu de Palomar                  0.0
# 20979                              NaN                  2.0
# 20980                     El Poble-sec                  1.0
#
#        host_total_listings_count  \
# 0                           39.0
# 1                            5.0
# 2                            1.0
# 3                           29.0
# 4                           29.0
# ...                          ...
# 20976                        1.0
# 20977                        3.0
# 20978                        0.0
# 20979                        2.0
# 20980                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 0      ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 1      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 2      ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 4      ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# ...                                                  ...                  ...
# 20976                                          ['phone']                    t
# 20977          ['email', 'phone', 'facebook', 'reviews']                    t
# 20978                                 ['email', 'phone']                    t
# 20979                                 ['email', 'phone']                    t
# 20980  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#       host_identity_verified                                 street  \
# 0                          t                   Barcelona, CT, Spain
# 1                          t  Sant Adria de Besos, Barcelona, Spain
# 2                          t            Barcelona, Barcelona, Spain
# 3                          f            Barcelona, Barcelona, Spain
# 4                          f            Barcelona, Barcelona, Spain
# ...                      ...                                    ...
# 20976                      f                   Barcelona, CT, Spain
# 20977                      f            Barcelona, Catalunya, Spain
# 20978                      f            Barcelona, Catalunya, Spain
# 20979                      f            Barcelona, Catalunya, Spain
# 20980                      t            Barcelona, Catalunya, Spain
#
#                          neighbourhood              neighbourhood_cleansed  \
# 0                   La Sagrada Família                  la Sagrada Família
# 1                           Sant Martí               el Besòs i el Maresme
# 2                       Vila de Gràcia                   la Vila de Gràcia
# 3      Camp d'en Grassot i Gràcia Nova  el Camp d'en Grassot i Gràcia Nova
# 4                               Gràcia  el Camp d'en Grassot i Gràcia Nova
# ...                                ...                                 ...
# 20976                   La Barceloneta                      la Barceloneta
# 20977                      El Poblenou   el Parc i la Llacuna del Poblenou
# 20978           Sant Andreu de Palomar                         Sant Andreu
# 20979   La Nova Esquerra de l'Eixample      la Nova Esquerra de l'Eixample
# 20980                     Ciutat Vella      la Nova Esquerra de l'Eixample
#
#       neighbourhood_group_cleansed                 city      state zipcode  \
# 0                         Eixample            Barcelona         CT   08025
# 1                       Sant Martí  Sant Adria de Besos  Barcelona   08930
# 2                           Gràcia            Barcelona  Barcelona   08012
# 3                           Gràcia            Barcelona  Barcelona   08024
# 4                           Gràcia            Barcelona  Barcelona   08024
# ...                            ...                  ...        ...     ...
# 20976                 Ciutat Vella            Barcelona         CT    8003
# 20977                   Sant Martí            Barcelona  Catalunya    8005
# 20978                  Sant Andreu            Barcelona  Catalunya    8030
# 20979                     Eixample            Barcelona  Catalunya    8015
# 20980                     Eixample            Barcelona  Catalunya    8015
#
#           market              smart_location country_code country   latitude  \
# 0      Barcelona            Barcelona, Spain           ES   Spain  41.404200
# 1      Barcelona  Sant Adria de Besos, Spain           ES   Spain  41.412910
# 2      Barcelona            Barcelona, Spain           ES   Spain  41.401450
# 3      Barcelona            Barcelona, Spain           ES   Spain  41.409500
# 4      Barcelona            Barcelona, Spain           ES   Spain  41.409280
# ...          ...                         ...          ...     ...        ...
# 20976  Barcelona            Barcelona, Spain           ES   Spain  41.378584
# 20977  Barcelona            Barcelona, Spain           ES   Spain  41.396652
# 20978  Barcelona            Barcelona, Spain           ES   Spain  41.436209
# 20979  Barcelona            Barcelona, Spain           ES   Spain  41.381451
# 20980  Barcelona            Barcelona, Spain           ES   Spain  41.379949
#
#        longitude is_location_exact property_type        room_type  \
# 0       2.173060                 t     Apartment  Entire home/apt
# 1       2.220630                 f     Apartment  Entire home/apt
# 2       2.156450                 t     Apartment     Private room
# 3       2.159380                 t     Apartment  Entire home/apt
# 4       2.161120                 t     Apartment  Entire home/apt
# ...          ...               ...           ...              ...
# 20976   2.191273                 f     Apartment     Private room
# 20977   2.193025                 f     Apartment     Private room
# 20978   2.185923                 t     Apartment     Private room
# 20979   2.155175                 f     Apartment  Entire home/apt
# 20980   2.150185                 t     Apartment     Private room
#
#        accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0                 8        2.0       3.0   6.0  Real Bed
# 1                 6        2.0       3.0   5.0  Real Bed
# 2                 2        1.0       1.0   1.0  Real Bed
# 3                 4        1.0       1.0   1.0  Real Bed
# 4                 5        1.5       3.0   3.0  Real Bed
# ...             ...        ...       ...   ...       ...
# 20976             1        1.0       1.0   NaN  Real Bed
# 20977             1        1.0       0.0   0.0  Real Bed
# 20978             1        2.0       1.0   1.0  Real Bed
# 20979             3        1.0       1.0   2.0  Real Bed
# 20980             1        1.5       1.0   NaN  Real Bed
#
#                                                amenities  square_feet  \
# 0      {TV,Internet,Wifi,"Air conditioning","Wheelcha...          NaN
# 1      {TV,Internet,Wifi,"Wheelchair accessible",Kitc...          NaN
# 2      {TV,Wifi,"Air conditioning",Kitchen,"Smoking a...          NaN
# 3      {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...          NaN
# 4      {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...          NaN
# ...                                                  ...          ...
# 20976  {TV,"Air conditioning",Kitchen,"Smoking allowe...          NaN
# 20977              {Kitchen,Elevator,Washer,"Hot water"}          NaN
# 20978  {Wifi,Kitchen,Essentials,Shampoo,"Lock on bedr...          NaN
# 20979  {TV,Wifi,"Air conditioning",Kitchen,"Paid park...          NaN
# 20980  {TV,Wifi,Kitchen,"Smoking allowed",Washer,Esse...          NaN
#
#          price weekly_price monthly_price security_deposit cleaning_fee  \
# 0       $85.00          NaN           NaN          $150.00       $50.00
# 1      $220.00          NaN           NaN          $300.00       $80.00
# 2       $32.00          NaN           NaN              NaN          NaN
# 3       $58.00          NaN           NaN          $200.00       $58.00
# 4       $63.00          NaN           NaN          $200.00      $108.00
# ...        ...          ...           ...              ...          ...
# 20976   $30.00          NaN           NaN              NaN          NaN
# 20977   $35.00          NaN           NaN              NaN          NaN
# 20978   $20.00          NaN           NaN              NaN          NaN
# 20979  $148.00          NaN           NaN              NaN          NaN
# 20980   $18.00          NaN           NaN              NaN          NaN
#
#        guests_included extra_people  minimum_nights  maximum_nights  \
# 0                    2       $30.00               1            1125
# 1                    3       $10.00               3              30
# 2                    1       $25.00               1             730
# 3                    4        $0.00               1              27
# 4                    5        $0.00               1              27
# ...                ...          ...             ...             ...
# 20976                1        $0.00               1            1125
# 20977                1        $0.00               3            1125
# 20978                1        $0.00              30             120
# 20979                1        $0.00               1            1125
# 20980                1        $0.00              30              90
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 0                           1                       7                    1125
# 1                           3                       7                    1125
# 2                           1                       1                     730
# 3                           1                       3                      27
# 4                           1                       3                      27
# ...                       ...                     ...                     ...
# 20976                       1                       1                    1125
# 20977                       3                       3                    1125
# 20978                      30                      30                    1125
# 20979                       1                       4                    1125
# 20980                      30                      30                      90
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0                        1125                     3.3                  1125.0
# 1                        1125                     3.2                  1125.0
# 2                         730                     1.0                   730.0
# 3                          27                     2.0                    27.0
# 4                          27                     2.0                    27.0
# ...                       ...                     ...                     ...
# 20976                    1125                     1.0                  1125.0
# 20977                    1125                     3.0                  1125.0
# 20978                    1125                    30.0                  1125.0
# 20979                    1125                     1.2                  1125.0
# 20980                      90                    30.0                    90.0
#
#       calendar_updated has_availability  availability_30  availability_60  \
# 0                today                t               21               26
# 1           3 days ago                t               29               59
# 2                today                t                2               24
# 3                today                t                3               17
# 4                today                t               10               26
# ...                ...              ...              ...              ...
# 20976            today                t               13               13
# 20977            today                t               14               14
# 20978            never                t               30               60
# 20979            today                t                9               37
# 20980            today                t               28               58
#
#        availability_90  availability_365 calendar_last_scraped  \
# 0                   44               258            2020-02-16
# 1                   86               347            2020-02-16
# 2                   45               122            2020-02-16
# 3                   42               262            2020-02-16
# 4                   48               274            2020-02-16
# ...                ...               ...                   ...
# 20976               13                13            2020-02-16
# 20977               14                14            2020-02-16
# 20978               90               365            2020-02-16
# 20979               59               332            2020-02-16
# 20980               88               363            2020-02-16
#
#        number_of_reviews  number_of_reviews_ltm first_review last_review  \
# 0                     21                     15   2013-05-27  2019-11-01
# 1                     52                     17   2011-03-15  2019-12-15
# 2                    269                     45   2010-08-11  2019-11-14
# 3                    187                     33   2011-02-19  2020-01-07
# 4                     91                     23   2011-01-07  2019-11-05
# ...                  ...                    ...          ...         ...
# 20976                  0                      0          NaN         NaN
# 20977                  0                      0          NaN         NaN
# 20978                  0                      0          NaN         NaN
# 20979                  0                      0          NaN         NaN
# 20980                  0                      0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 0                      88.0                     9.0
# 1                      95.0                    10.0
# 2                      95.0                    10.0
# 3                      91.0                     9.0
# 4                      88.0                     9.0
# ...                     ...                     ...
# 20976                   NaN                     NaN
# 20977                   NaN                     NaN
# 20978                   NaN                     NaN
# 20979                   NaN                     NaN
# 20980                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           10.0                   10.0
# 1                           10.0                   10.0
# 2                            9.0                   10.0
# 3                            9.0                    8.0
# 4                            9.0                    9.0
# ...                          ...                    ...
# 20976                        NaN                    NaN
# 20977                        NaN                    NaN
# 20978                        NaN                    NaN
# 20979                        NaN                    NaN
# 20980                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                    10.0
# 1                             10.0                     9.0
# 2                             10.0                    10.0
# 3                              9.0                     9.0
# 4                              9.0                     9.0
# ...                            ...                     ...
# 20976                          NaN                     NaN
# 20977                          NaN                     NaN
# 20978                          NaN                     NaN
# 20979                          NaN                     NaN
# 20980                          NaN                     NaN
#
#        review_scores_value requires_license      license  jurisdiction_names  \
# 0                      9.0                t  HUTB-002062                 NaN
# 1                      9.0                t  HUTB-005057                 NaN
# 2                     10.0                t          NaN                 NaN
# 3                      9.0                t  HUTB-004554                 NaN
# 4                      9.0                t  HUTB-005373                 NaN
# ...                    ...              ...          ...                 ...
# 20976                  NaN                t       Exempt                 NaN
# 20977                  NaN                t       Exempt                 NaN
# 20978                  NaN                t          NaN                 NaN
# 20979                  NaN                t       Exempt                 NaN
# 20980                  NaN                t          NaN                 NaN
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                    t                        f  strict_14_with_grace_period
# 1                    t                        f  strict_14_with_grace_period
# 2                    t                        f  strict_14_with_grace_period
# 3                    t                        f  strict_14_with_grace_period
# 4                    t                        f  strict_14_with_grace_period
# ...                ...                      ...                          ...
# 20976                t                        f                     flexible
# 20977                t                        f                     flexible
# 20978                t                        f                     flexible
# 20979                f                        f                     moderate
# 20980                f                        f                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                t
# 2                                 t                                t
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 20976                             f                                f
# 20977                             f                                f
# 20978                             f                                f
# 20979                             f                                f
# 20980                             f                                f
#
#        calculated_host_listings_count  \
# 0                                  24
# 1                                   4
# 2                                   1
# 3                                  29
# 4                                  29
# ...                               ...
# 20976                               1
# 20977                               3
# 20978                               2
# 20979                               1
# 20980                               2
#
#        calculated_host_listings_count_entire_homes  \
# 0                                               24
# 1                                                4
# 2                                                0
# 3                                               29
# 4                                               29
# ...                                            ...
# 20976                                            0
# 20977                                            1
# 20978                                            0
# 20979                                            1
# 20980                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 1
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 20976                                             1
# 20977                                             1
# 20978                                             2
# 20979                                             0
# 20980                                             2
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0               0.26
# 1                                                0               0.48
# 2                                                0               2.32
# 3                                                0               1.71
# 4                                                0               0.82
# ...                                            ...                ...
# 20976                                            0                NaN
# 20977                                            1                NaN
# 20978                                            0                NaN
# 20979                                            0                NaN
# 20980                                            0                NaN
#
# [20981 rows x 106 columns]

# %%
# %%time
calendar_detailed = pd.read_csv("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/data/calendar.csv.gz")
# Out:
# CPU times: user 6.36 s, sys: 2.01 s, total: 8.37 s
# Wall time: 21.3 s

# %%
calendar_detailed.shape
# Out:
# (7658211, 7)

# %%
# %%time
reviews_detailed = pd.read_csv("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/data/reviews.csv.gz")
# Out:
# CPU times: user 6.15 s, sys: 2.03 s, total: 8.18 s
# Wall time: 36.8 s

# %%
reviews_detailed.shape
# Out:
# (753366, 6)

# %%
# %%time
listings_summary = pd.read_csv("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/data/listings.csv")
# Out:
# CPU times: user 1.77 s, sys: 1.17 s, total: 2.94 s
# Wall time: 32.8 s

# %%
listings_summary.shape
# Out:
# (20981, 106)

# %%
# %%time
reviews_summary = pd.read_csv("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/data/reviews.csv")
# Out:
# CPU times: user 5.2 s, sys: 3.65 s, total: 8.84 s
# Wall time: 1min 8s

# %%
reviews_summary.shape
# Out:
# (753366, 6)

# %%
# %%time
neighbourhoods_csv = pd.read_csv("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/visualisations/neighbourhoods.csv")
# Out:
# CPU times: user 5.23 ms, sys: 8.16 ms, total: 13.4 ms
# Wall time: 281 ms

# %%
neighbourhoods_csv.shape
# Out:
# (73, 2)

# %%
# %%time
neighbourhoods_json = gpd.read_file("http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/visualisations/neighbourhoods.geojson")
# Out:
# CPU times: user 132 ms, sys: 48.5 ms, total: 181 ms
# Wall time: 950 ms

# %%
gdf = gpd.GeoDataFrame(listings_detailed, geometry=gpd.points_from_xy(listings_detailed.longitude, listings_detailed.latitude))
base = neighbourhoods_json.geometry.plot(color='white', edgecolor='.5', linewidth=1);
gdf.plot(marker='.', ax=base, alpha=0.1, column='price_log', legend=True, s=2);
plt.axis('off')
# Out:
# (2.0436325, 2.2380575000000005, 41.3093897, 41.4758483)

# %%
gdf.price.plot.hist(bins=100)

# %%
gdf.price.plot.box()

# %%
gdf.price_log.plot.box()
