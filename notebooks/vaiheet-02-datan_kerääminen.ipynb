# %% [markdown]
# ## Datan kerääminen
#
# Datan kerääminen on AirBnB-datan osalta poikkeuksellisen yksinkertaista johtuen pitkälti siitä, että data on jo kerätty. Analyysikelpoisen datan lataaminen onnistuu one-linerilla.

# %%
import pandas as pd
ld_backup = pd.read_csv(f"http://data.insideairbnb.com/spain/catalonia/barcelona/2020-02-16/data/listings.csv.gz")
ld_backup.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  18674  https://www.airbnb.com/rooms/18674  20200216165356   2020-02-16
# 1  23197  https://www.airbnb.com/rooms/23197  20200216165356   2020-02-16
# 2  25786  https://www.airbnb.com/rooms/25786  20200216165356   2020-02-16
# 3  31958  https://www.airbnb.com/rooms/31958  20200216165356   2020-02-16
# 4  32471  https://www.airbnb.com/rooms/32471  20200216165356   2020-02-16
#
#                                               name  \
# 0  Huge flat for 8 people close to Sagrada Familia
# 1  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
# 2       NICE ROOM AVAILABLE IN THE HEART OF GRACIA
# 3                  Gaudi Attic 1, Friendly Rentals
# 4                  Gaudi Attic 2, Friendly Rentals
#
#                                              summary  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  I do not accept groups of young people under 2...
# ...

# %% [markdown]
# 1/3 p.
